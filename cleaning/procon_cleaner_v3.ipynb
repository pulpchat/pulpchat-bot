# %%
import csv
import openai

# %%
if __name__ == "__main__":
    openai.api_key = "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"  # supply your API key however you choose

# %%
def ask(content):
        response = openai.Completion.create(
                model="text-davinci-003",
                prompt=content,
                temperature=0,
                max_tokens=2000,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0
                )
        return(response.choices[0].text)

# %%
prompt = """
For each item in the list below, turn the questions into 2 "claims", positive and negative:\
List: {{list}}\

Only return a JSON object. Use the following JSON schema:\

{\
"questions_and_claims":[{\
"original_question":,\
"claim_positive":,\
"claim_negative":,\
}]\
}\
"""

# %%
def writeout(content, file):
    with open(file, 'w') as clean_titles:
        clean_titles.write(content)

# %%
#with open("/Users/pulpdesign/Pulp Dropbox/Shah Ullah/My Mac (PULPs-MBP.lan)/Downloads/titles.csv") as file:

# %%
list_content = ""

with open("/Users/pulpdesign/Pulp Dropbox/Shah Ullah/My Mac (PULPs-MBP.lan)/Downloads/titles.csv") as file:
    
    lines = file.readlines()
    
    for line in lines[1:len(lines)-1]:
        list_content += line
    
    prompt = prompt.replace("{{list}}", list_content)

    data = ask(prompt)
    print(data)
    
   #writeout(data, "./clean_titles.json")

# %%
## cleaner_______@@@@@@@@@@@@@@
list_content = ""

with open("/Users/pulpdesign/Pulp Dropbox/Shah Ullah/My Mac (PULPs-MBP.lan)/Downloads/a_to_z_debates_dirty.csv") as file:
    
    lines = file.readlines()
    len_lines = len(lines)
    
    
    for i in range(0, len_lines-1):           
        if (len(lines[i]) != (2) and len(lines[i]) !=3):
            line_array = lines[i].split(',', 1)
            debate_question = str(line_array[1]).strip()
            debate_question = debate_question.strip('"')
            if " " in debate_question[0:2]:
                question_array = ""
                p = 0
                while p != len(debate_question)-1:
                    question_array += debate_question[p+1]
                    p += 1
                debate_question = str(question_array)
                #print(question_array)
        
            debate_topic = line_array[0].upper()
            #list_content += debate_topic + "\n"
            list_content += debate_question + "\n"
        i += 1
            
    print(list_content)
    #archived_topics = ""
    #archived_topics = list_content.split("ARCHIVED TOPICS")[1]
    
    writeout(list_content, "./clean_debates_full_v3.csv")
    #writeout(archived_topics, "./archived_debates_full_v2.csv")
# Out:
# should abortion be legal?
# can alternative energy effectively replace fossil fuels?
# should the u.s. become socialist?
# should k-12 students dissect animals in science classrooms?
# should animals be used for scientific or commercial testing?
# is artificial intelligence good for society?
# should parents or other adults be able to ban books from schools and libraries?
# is binge-watching good for you?
# should bottled water be banned?
# is cancel culture (or callout culture) good for society?
# is cbd good for pets?
# is cell phone radiation safe?
# should churches (including mosques, synagogues, etc.) remain tax-exempt?
# is human activity primarily responsible for global climate change?
# is a college education worth it?
# should adults have the right to carry a concealed handgun?
# should corporal punishment be used in k-12 schools?
# should the federal corporate income tax rate be raised?
# should the united states maintain its embargo against cuba?
# ...

# %%
list_content = ""

with open("/Users/pulpdesign/Pulp Dropbox/Shah Ullah/My Mac (PULPs-MBP.lan)/Desktop/pulpcode/pulpchat-bot/cleaning/clean_debates_full_v3.csv") as file:
    total_data = ""
    lines = file.readlines()
    
    for i in range(0, len(lines)-1, 10):
        line_content = ""
        if i > 79:
            for l in lines[i:len(lines)-1]:
                line_content += (lines[i] + "\n")
                prompt = prompt.replace("{{list}}", line_content)
                print("prompt", str(i), prompt)
                data = ask(prompt)
                print(data)
                
                writeout(data, ("./full_debate_questions_" + i + ".json"))
            
        
        for j in range(i, len(lines)-1):
            list_content += (lines[i] + "\n")
            prompt = prompt.replace("{{list}}", list_content)
            print(prompt)
            data = ask(prompt)
            print(data)
    
            writeout(data, ("./full_debate_questions_" + i + ".json"))
# Out:
# For each item in the list below, turn the questions into 2 "claims", positive and negative:List: should abortion be legal?
# can alternative energy effectively replace fossil fuels?
# should the u.s. become socialist?
# should k-12 students dissect animals in science classrooms?
# should animals be used for scientific or commercial testing?
# is artificial intelligence good for society?
# should parents or other adults be able to ban books from schools and libraries?
# is binge-watching good for you?
# should bottled water be banned?
# is cancel culture (or callout culture) good for society?
# is cbd good for pets?
# is cell phone radiation safe?
# should churches (including mosques, synagogues, etc.) remain tax-exempt?
# is human activity primarily responsible for global climate change?
# is a college education worth it?
# should adults have the right to carry a concealed handgun?
# should corporal punishment be used in k-12 schools?
# ...

# %%
list_content = ""

with open("/Users/pulpdesign/Pulp Dropbox/Shah Ullah/My Mac (PULPs-MBP.lan)/Desktop/pulpcode/pulpchat-bot/cleaning/clean_debates_full_v3.csv") as file:
    total_data = ""
    lines = file.readlines()
    
    for line in lines:
        list_content += (line")
        prompt = prompt.replace("{{list}}", list_content)
        
        print(prompt)
        data = ask(prompt)
        print(data)
    
    writeout(data, ("./full_debate_questions_" + pos + ".json"))

# %%
list_content = ""

with open("/Users/pulpdesign/Pulp Dropbox/Shah Ullah/My Mac (PULPs-MBP.lan)/Desktop/pulpcode/pulpchat-bot/cleaning/clean_debates_full_v3.csv") as file:
    total_data = ""
    lines = file.readlines()
    
    for i in range(0, len(lines)-1, 10):
        line_content = ""
        if i > 79:
            for l in lines[i:len(lines)-1]:
                line_content += (lines[i] + "\n")
                prompt = prompt.replace("{{list}}", line_content)
                print("prompt", str(i), prompt)
                data = ask(prompt)
                print(data)
                
                writeout(data, ("./full_debate_questions_" + i + ".json"))
            
        
        for j in range(i, len(lines)-1):
            list_content += (lines[i] + "\n")
            prompt = prompt.replace("{{list}}", list_content)
            print(prompt)
            data = ask(prompt)
            print(data)
    
            writeout(data, ("./full_debate_questions_" + i + ".json"))
